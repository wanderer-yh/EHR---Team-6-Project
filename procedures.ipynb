# %%
import numpy as np
import pandas as pd
import os
import datetime
os.getcwd()
# Out:
# 'c:\\Users\\Student\\Documents\\EHR---Team-6-Project'

# %%
procedures = pd.read_csv('data/coherent-11-07-2022/csv/procedures.csv')

# %%
procedures.columns
# Out:
# Index(['DATE', 'PATIENT', 'ENCOUNTER', 'CODE', 'DESCRIPTION', 'BASE_COST',
#        'REASONCODE', 'REASONDESCRIPTION'],
#       dtype='object')

# %%
#View list of unique procedures
procedures['DESCRIPTION'].unique()
# Out:
# array(['Colonoscopy', 'Digital examination of rectum',
#        'Medication Reconciliation (procedure)', 'Biopsy of prostate',
#        'Suture open wound', 'Injection of tetanus antitoxin',
#        'Standard pregnancy test', 'Ultrasound scan for fetal viability',
#        'Counseling for termination of pregnancy',
#        'Induced termination of pregnancy', 'RhD passive immunization',
#        'Pregnancy termination care', 'Physical exam following abortion',
#        'Depression screening', 'Evaluation of uterine fundal height',
#        'Auscultation of the fetal heart', 'Blood typing  RH typing',
#        'Hemoglobin / Hematocrit / Platelet count',
#        'Hepatitis B Surface Antigen Measurement',
#        'Human immunodeficiency virus antigen test',
#        'Chlamydia antigen test', 'Gonorrhea infection test',
#        'Syphilis infection test', 'Urine culture',
#        'Cytopathology procedure  preparation of smear  genital source',
# ...

# %%
# Create list of chemo/radiation procedures
cancer_procedures = ['Combined chemotherapy and radiation therapy (procedure)',
       'Chemotherapy (procedure)',
       'Teleradiotherapy procedure (procedure)',
       'Radiation therapy care (regime/therapy)',
       'Radiation oncology AND/OR radiotherapy (procedure)',
       'Brachytherapy of breast (procedure)',
       'Interstitial brachytherapy (procedure)']

# %%
# Search for patients who have received procedures in the list above
procedure_pats = procedures[procedures['DESCRIPTION'].isin(cancer_procedures)]
procedure_pats.PATIENT.unique().shape  # 275 unique patients have received above procedures
# Out:
# (275,)

# %%
Import chemo patients list from other file
chemo_pats = pd.read_csv('chemo_pats.csv')

# %%
# Compare lists to see if there are patients not captured in the chemo list
procedure_pats['PATIENT'].isin(chemo_pats['PATIENT']).value_counts()
# Out:
# True     7879
# False     102
# Name: PATIENT, dtype: int64

# %%
# Create a df of the patients not in the chemo list--it looks like they only receiveed radiation
Missed = procedure_pats[procedure_pats['PATIENT'].isin(chemo_pats['PATIENT'])==False]
Missed
# Out:
#                        DATE                               PATIENT  \
# 18205  2020-07-27T08:55:43Z  2eda093a-4700-5bbb-11d4-9188b234bbe4
# 18206  2020-07-28T11:20:43Z  2eda093a-4700-5bbb-11d4-9188b234bbe4
# 18207  2020-07-29T15:58:43Z  2eda093a-4700-5bbb-11d4-9188b234bbe4
# 18208  2020-07-30T18:24:43Z  2eda093a-4700-5bbb-11d4-9188b234bbe4
# 18209  2020-08-01T04:02:43Z  2eda093a-4700-5bbb-11d4-9188b234bbe4
# ...                     ...                                   ...
# 93102  2021-04-28T23:41:01Z  de713898-01c1-58d6-4ab9-11d0337a59f7
# 93103  2021-04-30T01:20:01Z  de713898-01c1-58d6-4ab9-11d0337a59f7
# 93104  2021-05-01T08:54:01Z  de713898-01c1-58d6-4ab9-11d0337a59f7
# 93105  2021-05-02T19:14:01Z  de713898-01c1-58d6-4ab9-11d0337a59f7
# 93106  2021-05-03T22:31:01Z  de713898-01c1-58d6-4ab9-11d0337a59f7
#
#                                   ENCOUNTER       CODE  \
# 18205  4bb2b1f1-c5da-2527-d53f-c17081ed004f  108290001
# 18206  94cab814-d520-b006-f348-f3af75a7ae85  108290001
# ...
